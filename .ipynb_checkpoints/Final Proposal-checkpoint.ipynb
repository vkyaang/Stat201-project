# %% [markdown]
# # Introduction

# %% [markdown]
# Our report utilizes data from the Vancouver Police Department to study crime report trends across different neighborhoods in Vancouver [2]. This study has the potential to assist the police in identifying areas with a higher probability of crime activities, thereby enabling them to strategically distribute and allocate their human resources to maximize effectiveness. To achieve this, we selected all years of crime data avaliable to improve the accuracy of our estimations. Maximizing the use of human resources is crucial in possibly minimizing the crime level.
#
# The rationale behind selecting data from all years is to leverage historical data to estimate the proportions effectively. By considering multiple years of data, we gain a broader perspective on crime patterns, enabling us to identify long-term trends and potential seasonality [3]. This approach leads to more accurate estimations as compared to relying solely on data from a single year, which might be influenced by external factors such as the pandemic.
#
# To substantiate our observations, we have devised a hypothesis test to compare the proportion of "theft from vehicle" in all crime reports between two locations, Mount Pleasant and Strathcona, relying on their respective sample proportions and another hypothesis test comparing the proportion of "crimes against a person" between Mount Pleasant and Strathcona.
#
# The reason behind conducting this hypothesis test is to examine whether the proportion of "theft from vehicle" in Mount Pleasant differs from that in Strathcona. Given the similarity in crime report rates between the two areas, we aim to investigate whether "theft from vehicle" is the primary reason for the high crime rate in Mount Pleasant. To achieve this, we have formulated the null hypothesis, assuming that the difference in the proportion of theft from vehicle between Mount Pleasant and Strathcona is zero. On the other hand, the alternative hypothesis posits that the proportion of theft from vehicle in Mount Pleasant is indeed greater than that in Strathcona.
#
# Similarly, the hypothesis test for "crime against person" aims to explore whether this specific type of crime is a significant contributing factor to the higher crime rate observed in Strathcona, as compared to Mount Pleasant. The null hypothesis posits that the proportion of "crime against person" in Strathcona is equal to that in Mount Pleasant. On the other hand, the alternative hypothesis suggests that the proportion of "crime against person" in Strathcona is greater than that in Mount Pleasant.

# %%
library(tidyverse)
library(repr)
library(datateachr)
library(digest)
library(infer)
library(gridExtra)
library(cowplot)
library(broom)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.4
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
crime_data <- read_csv("https://raw.githubusercontent.com/vkyaang/Stat201-project/main/crimedata_csv_AllNeighbourhoods_AllYears.csv") %>%
    mutate(TYPE = as_factor(TYPE),
          NEIGHBOURHOOD = as_factor(NEIGHBOURHOOD)) %>%
    drop_na()
head(crime_data)
# Out:
# Rows: 868146 Columns: 10
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): TYPE, HUNDRED_BLOCK, NEIGHBOURHOOD
# dbl (7): YEAR, MONTH, DAY, HOUR, MINUTE, X, Y
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   TYPE               YEAR MONTH DAY HOUR MINUTE HUNDRED_BLOCK
# 1 Theft from Vehicle 2008 12     7  18    0     11XX E HASTINGS ST
# 2 Theft from Vehicle 2009  8    28  19    0     11XX E HASTINGS ST
# 3 Theft from Vehicle 2012  7    25  12    0     11XX E HASTINGS ST
# 4 Theft from Vehicle 2014  5     8  12   49     11XX E HASTINGS ST
# 5 Theft from Vehicle 2014 10    19  18    0     11XX E HASTINGS ST
# 6 Theft from Vehicle 2015  2    18  18   30     11XX E HASTINGS ST
#   NEIGHBOURHOOD X        Y
# 1 Strathcona    494141.1 5458690
# 2 Strathcona    494141.1 5458690
# 3 Strathcona    494141.1 5458690
# 4 Strathcona    494141.1 5458690
# 5 Strathcona    494141.1 5458690
# 6 Strathcona    494141.1 5458690

# %%
# select crime_data with only chosen neighborhood and type
crime_data_clean <- crime_data %>%  
                    select(TYPE, NEIGHBOURHOOD) %>%
                    group_by(TYPE)

crime_data_total <- crime_data_clean %>%
    summarise(total = n())
    

# Separating the two neighbourhood to get a data summary
mount_pleasant_n <- crime_data_clean %>%  
    filter(NEIGHBOURHOOD == 'Mount Pleasant') %>%
    summarise(MountPleasent = n())

strathcona_n <- crime_data_clean %>%
    filter(NEIGHBOURHOOD == 'Strathcona') %>%
    summarise(Strathcona = n())

# Combining the datasets and finding proportion and other relevant data, presenrted in a form of a table
crime_data_sum <- crime_data_total %>%
    inner_join(mount_pleasant_n, by = 'TYPE') %>%
    inner_join(strathcona_n, by = 'TYPE') %>%
    mutate(MountPleasent_prop = MountPleasent/sum(total)) %>%
    mutate(strathcona_prop = Strathcona/sum(total)) %>%
    mutate(prop_diff = MountPleasent_prop - strathcona_prop)


head(crime_data_clean)
# Out:
#   TYPE               NEIGHBOURHOOD
# 1 Theft from Vehicle Strathcona
# 2 Theft from Vehicle Strathcona
# 3 Theft from Vehicle Strathcona
# 4 Theft from Vehicle Strathcona
# 5 Theft from Vehicle Strathcona
# 6 Theft from Vehicle Strathcona

# %%
crime_data_total
# Out:
#    TYPE                                                   total
# 1  Theft from Vehicle                                     240856
# 2  Theft of Bicycle                                        36930
# 3  Theft of Vehicle                                        44710
# 4  Vehicle Collision or Pedestrian Struck (with Fatality)    347
# 5  Vehicle Collision or Pedestrian Struck (with Injury)    28839
# 6  Break and Enter Commercial                              47310
# 7  Break and Enter Residential/Other                       72174
# 8  Homicide                                                  309
# 9  Mischief                                               105195
# 10 Offence Against a Person                                75613
# 11 Other Theft                                            215709

# %%
crime_data_sum
# Out:
#    TYPE                                                   total  MountPleasent
# 1  Theft from Vehicle                                     240856 13345
# 2  Theft of Bicycle                                        36930  3955
# 3  Theft of Vehicle                                        44710  3118
# 4  Vehicle Collision or Pedestrian Struck (with Fatality)    347    21
# 5  Vehicle Collision or Pedestrian Struck (with Injury)    28839  2124
# 6  Break and Enter Commercial                              47310  4122
# 7  Break and Enter Residential/Other                       72174  3872
# 8  Homicide                                                  309    19
# 9  Mischief                                               105195  6102
# 10 Offence Against a Person                                75613  3836
# 11 Other Theft                                            215709 14167
#    Strathcona MountPleasent_prop strathcona_prop prop_diff
# 1  13161      1.537457e-02       1.516258e-02     0.0002119835
# 2   1692      4.556494e-03       1.949327e-03     0.0026071669
# 3   2250      3.592199e-03       2.592190e-03     0.0010000092
# 4     34      2.419377e-05       3.917087e-05    -0.0000149771
# 5   1559      2.447027e-03       1.796100e-03     0.0006509277
# 6   3146      4.748892e-03       3.624457e-03     0.0011244343
# 7   2681      4.460871e-03       3.088738e-03     0.0013721325
# 8     32      2.188960e-05       3.686670e-05    -0.0000149771
# 9   8142      7.030019e-03       9.380271e-03    -0.0023502521
# 10  9769      4.419396e-03       1.125471e-02    -0.0068353165
# 11 13278      1.632158e-02       1.529738e-02     0.0010242030

# %%
summary(crime_data_clean)
# Out:
#                                 TYPE                          NEIGHBOURHOOD
#  Theft from Vehicle               :240856   Central Business District:233260
#  Other Theft                      :215709   West End                 : 78052
#  Mischief                         :105195   Strathcona               : 55744
#  Offence Against a Person         : 75613   Mount Pleasant           : 54681
#  Break and Enter Residential/Other: 72174   Fairview                 : 53340
#  Break and Enter Commercial       : 47310   Grandview-Woodland       : 48805
#  (Other)                          :111135   (Other)                  :344110

# %%
# Getting the number of rows of  each crime time in the two neighbourhoods

dataMP <- crime_data_clean |>
            filter(NEIGHBOURHOOD == "Mount Pleasant") |>
            group_by(TYPE) |>
            summarize(n= n())



dataS <- crime_data_clean |>
            filter(NEIGHBOURHOOD == "Strathcona") |>
            group_by(TYPE) |>
            summarize(n= n())

dataMP
# Out:
#    TYPE                                                   n
# 1  Theft from Vehicle                                     13345
# 2  Theft of Bicycle                                        3955
# 3  Theft of Vehicle                                        3118
# 4  Vehicle Collision or Pedestrian Struck (with Fatality)    21
# 5  Vehicle Collision or Pedestrian Struck (with Injury)    2124
# 6  Break and Enter Commercial                              4122
# 7  Break and Enter Residential/Other                       3872
# 8  Homicide                                                  19
# 9  Mischief                                                6102
# 10 Offence Against a Person                                3836
# 11 Other Theft                                            14167

# %%
dataS
# Out:
#    TYPE                                                   n
# 1  Theft from Vehicle                                     13161
# 2  Theft of Bicycle                                        1692
# 3  Theft of Vehicle                                        2250
# 4  Vehicle Collision or Pedestrian Struck (with Fatality)    34
# 5  Vehicle Collision or Pedestrian Struck (with Injury)    1559
# 6  Break and Enter Commercial                              3146
# 7  Break and Enter Residential/Other                       2681
# 8  Homicide                                                  32
# 9  Mischief                                                8142
# 10 Offence Against a Person                                9769
# 11 Other Theft                                            13278

# %%
# Calculating the total crime reported
neighbor_total <- crime_data %>%
    select(NEIGHBOURHOOD) %>%
    summarise(n = n()) %>%
    pull()

# Finding the crime rate of Mount Pleasant
dataMP_prop <- dataMP |>
     summarize(total_number_of_crime= sum(n)) |>
     mutate(location = 'Mount Pleasant') |>
     mutate(prop = total_number_of_crime/neighbor_total) 


# Finding the crime rate of Strathcona
dataS_prop <- dataS |>
      summarize(total_number_of_crime= sum(n))  |>
      mutate(location = 'Strathcona') |>
      mutate(prop = total_number_of_crime/neighbor_total)

# %%
# Binding the two crime rates
proportion <- rbind(dataS_prop, dataMP_prop) 

proportion
# Out:
#   total_number_of_crime location       prop
# 1 55744                 Strathcona     0.06422179
# 2 54681                 Mount Pleasant 0.06299712

# %%
# Plotting the crime rates
options(repr.plot.width = 6, repr.plot.height = 5)
prop_plot <- proportion %>%
    ggplot(aes(x=location, y=prop)) +
    geom_bar(stat = 'identity') +
    labs(y='Neighborhood', x='Proportion') +
    ggtitle('Proportion of All Crimes for Mount Pleasant and Strathcona ') +
    theme(axis.text.x = element_text(size=15))

prop_plot
# Out:
# plot without title

# %%
# Plotting Proportions of different types of crimes in Mount Pleasant
options(repr.plot.width = 12, repr.plot.height = 10)
mountpleasant_sum_plot <- crime_data_sum %>%
    ggplot(aes(x=TYPE, y= MountPleasent_prop, fill=TYPE)) +
    geom_bar(stat = 'identity') +
    labs(y='Proportion(Mount Pleasant)', x='Type of Crimes') +
    ggtitle('Mount Pleasant Proportion of All Crimes') +
    theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1, size=15))

# Plotting Proportions of different types of crimes in Strathacona
options(repr.plot.width = 15, repr.plot.height = 10)
strathcona_sum_plot <- crime_data_sum %>%
    ggplot(aes(x=TYPE, y=strathcona_prop, fill=TYPE)) +
    geom_bar(stat = 'identity') +
    labs(y='Proportion(Strathcona)', x='Type of Crimes') +
    ggtitle('Strathconat Proportion of All Crimes') +
    theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1, size=15))

# %%
mountpleasant_sum_plot
# Out:
# plot without title

# %%
strathcona_sum_plot
# Out:
# plot without title

# %%
options(repr.plot.width = 13, repr.plot.height = 8)

mp_prop <- crime_data_sum %>%
    select(MountPleasent_prop, TYPE) %>%
    mutate(neighborhood = 'Mount Pleasant', 
          prop = MountPleasent_prop) %>%
    select(-MountPleasent_prop)

s_prop <- crime_data_sum %>%
    select(strathcona_prop, TYPE) %>%
    mutate(neighborhood = 'Strathconat', 
          prop = strathcona_prop)  %>%
    select(-strathcona_prop)

    
all_prop <- rbind(mp_prop, s_prop)

combined_prop_plot <- all_prop %>%
    ggplot(aes(x=TYPE, y=prop, fill = neighborhood)) +
    geom_bar(stat = 'identity', position = "dodge") +
    labs(y='Proportion', x='Type of Crimes', legend= 'Neighborhood') +
    ggtitle('Strathconat and Mount Pleasant Proportion of All Crimes') +
    theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1, size=15)) +
    coord_flip()

combined_prop_plot
# Out:
# plot without title

# %%
crime_new <- crime_data %>%
    select(TYPE, NEIGHBOURHOOD)

n <- nrow(crime_new)

crime_mp_s <- crime_new %>%
    filter(TYPE %in% c("Theft from Vehicle", "Offence Against a Person") & NEIGHBOURHOOD %in% c("Strathcona	", "Mount Pleasant")) 

crime_theft <- crime_new %>%
    filter(NEIGHBOURHOOD %in% c("Strathcona	", "Mount Pleasant")) %>%
    mutate(is_theft = TYPE == "Theft from Vehicle")

tail(crime_mp_s)
tail(crime_theft)
n
# Out:
#   TYPE               NEIGHBOURHOOD
# 1 Theft from Vehicle Mount Pleasant
# 2 Theft from Vehicle Mount Pleasant
# 3 Theft from Vehicle Mount Pleasant
# 4 Theft from Vehicle Mount Pleasant
# 5 Theft from Vehicle Mount Pleasant
# 6 Theft from Vehicle Mount Pleasant
#   TYPE               NEIGHBOURHOOD  is_theft
# 1 Theft from Vehicle Mount Pleasant TRUE
# 2 Theft from Vehicle Mount Pleasant TRUE
# 3 Theft from Vehicle Mount Pleasant TRUE
# 4 Theft from Vehicle Mount Pleasant TRUE
# 5 Theft from Vehicle Mount Pleasant TRUE
# 6 Theft from Vehicle Mount Pleasant TRUE
# [1] 867992

# %%
crime_is_theft_sum <- crime_data %>%  
        select(TYPE, NEIGHBOURHOOD) %>%
        filter(NEIGHBOURHOOD == "Strathcona" | NEIGHBOURHOOD =="Mount Pleasant") %>%
        mutate(is_theft = TYPE == "Theft from Vehicle") %>%
        group_by(NEIGHBOURHOOD) %>%
        count(is_theft) %>%
        mutate(prop = n/sum(n))

crime_is_theft_sum
# Out:
#   NEIGHBOURHOOD  is_theft n     prop
# 1 Strathcona     FALSE    42583 0.7639028
# 2 Strathcona      TRUE    13161 0.2360972
# 3 Mount Pleasant FALSE    41336 0.7559481
# 4 Mount Pleasant  TRUE    13345 0.2440519

# %%
# confidence interval theft

mount_pleasant <- crime_data %>%  
    select(TYPE, NEIGHBOURHOOD) %>%
    filter(NEIGHBOURHOOD == 'Mount Pleasant')

strathcona <- crime_data %>%  
    select(TYPE, NEIGHBOURHOOD) %>%
    filter(NEIGHBOURHOOD == 'Strathcona')

mount_pleasant_sample <- mount_pleasant %>%
    rep_sample_n(size = nrow(mount_pleasant), reps = 50, replace = TRUE) %>%
    group_by(replicate)

strathcona_sample <- strathcona %>%
    rep_sample_n(size = nrow(strathcona), reps = 50, replace = TRUE) %>%
    group_by(replicate)

head(mount_pleasant_sample)
head(strathcona_sample)
# Out:
#         replicate TYPE
# 1       1         Theft from Vehicle
# 2       1         Theft of Bicycle
# 3       1         Other Theft
# 4       1         Theft from Vehicle
# 5       1         Break and Enter Commercial
# 6       1         Break and Enter Residential/Other
# 7       1         Theft from Vehicle
# 8       1         Mischief
# 9       1         Theft of Vehicle
# 10      1         Other Theft
# 11      1         Other Theft
# 12      1         Break and Enter Residential/Other
# 13      1         Theft from Vehicle
# 14      1         Mischief
# 15      1         Other Theft
# 16      1         Break and Enter Commercial
# 17      1         Offence Against a Person
# 18      1         Theft from Vehicle
# 19      1         Theft from Vehicle
# 20      1         Theft from Vehicle
# 21      1         Break and Enter Residential/Other
# 22      1         Mischief
# 23      1         Vehicle Collision or Pedestrian Struck (with Injury)
# 24      1         Other Theft
# 25      1         Other Theft
# 26      1         Other Theft
# 27      1         Theft of Bicycle
# 28      1         Other Theft
# 29      1         Theft from Vehicle
# 30      1         Other Theft
# ⋮       ⋮         ⋮
# 2734021 50        Break and Enter Commercial
# 2734022 50        Theft from Vehicle
# 2734023 50        Theft of Bicycle
# 2734024 50        Theft from Vehicle
# 2734025 50        Vehicle Collision or Pedestrian Struck (with Injury)
# 2734026 50        Theft from Vehicle
# 2734027 50        Other Theft
# 2734028 50        Offence Against a Person
# 2734029 50        Offence Against a Person
# 2734030 50        Theft from Vehicle
# 2734031 50        Other Theft
# 2734032 50        Theft of Bicycle
# 2734033 50        Offence Against a Person
# 2734034 50        Break and Enter Commercial
# 2734035 50        Vehicle Collision or Pedestrian Struck (with Injury)
# 2734036 50        Theft from Vehicle
# 2734037 50        Other Theft
# 2734038 50        Theft from Vehicle
# 2734039 50        Other Theft
# 2734040 50        Theft of Bicycle
# 2734041 50        Theft from Vehicle
# 2734042 50        Offence Against a Person
# 2734043 50        Break and Enter Residential/Other
# 2734044 50        Theft from Vehicle
# 2734045 50        Other Theft
# 2734046 50        Break and Enter Residential/Other
# 2734047 50        Theft of Bicycle
# 2734048 50        Break and Enter Residential/Other
# 2734049 50        Theft of Bicycle
# 2734050 50        Other Theft
#         NEIGHBOURHOOD
# 1       Mount Pleasant
# 2       Mount Pleasant
# 3       Mount Pleasant
# 4       Mount Pleasant
# 5       Mount Pleasant
# 6       Mount Pleasant
# 7       Mount Pleasant
# 8       Mount Pleasant
# 9       Mount Pleasant
# 10      Mount Pleasant
# 11      Mount Pleasant
# 12      Mount Pleasant
# 13      Mount Pleasant
# 14      Mount Pleasant
# 15      Mount Pleasant
# 16      Mount Pleasant
# 17      Mount Pleasant
# 18      Mount Pleasant
# 19      Mount Pleasant
# 20      Mount Pleasant
# 21      Mount Pleasant
# 22      Mount Pleasant
# 23      Mount Pleasant
# 24      Mount Pleasant
# 25      Mount Pleasant
# 26      Mount Pleasant
# 27      Mount Pleasant
# 28      Mount Pleasant
# 29      Mount Pleasant
# 30      Mount Pleasant
# ⋮       ⋮
# 2734021 Mount Pleasant
# 2734022 Mount Pleasant
# 2734023 Mount Pleasant
# 2734024 Mount Pleasant
# 2734025 Mount Pleasant
# 2734026 Mount Pleasant
# 2734027 Mount Pleasant
# 2734028 Mount Pleasant
# 2734029 Mount Pleasant
# 2734030 Mount Pleasant
# 2734031 Mount Pleasant
# 2734032 Mount Pleasant
# 2734033 Mount Pleasant
# 2734034 Mount Pleasant
# 2734035 Mount Pleasant
# 2734036 Mount Pleasant
# 2734037 Mount Pleasant
# 2734038 Mount Pleasant
# 2734039 Mount Pleasant
# 2734040 Mount Pleasant
# 2734041 Mount Pleasant
# 2734042 Mount Pleasant
# 2734043 Mount Pleasant
# 2734044 Mount Pleasant
# 2734045 Mount Pleasant
# 2734046 Mount Pleasant
# 2734047 Mount Pleasant
# 2734048 Mount Pleasant
# 2734049 Mount Pleasant
# 2734050 Mount Pleasant
#         replicate TYPE
# 1       1         Theft of Vehicle
# 2       1         Theft from Vehicle
# 3       1         Other Theft
# 4       1         Mischief
# 5       1         Theft from Vehicle
# 6       1         Offence Against a Person
# 7       1         Other Theft
# 8       1         Other Theft
# 9       1         Theft from Vehicle
# 10      1         Break and Enter Commercial
# 11      1         Other Theft
# 12      1         Mischief
# 13      1         Theft from Vehicle
# 14      1         Break and Enter Commercial
# 15      1         Theft from Vehicle
# 16      1         Offence Against a Person
# 17      1         Theft from Vehicle
# 18      1         Offence Against a Person
# 19      1         Other Theft
# 20      1         Offence Against a Person
# 21      1         Offence Against a Person
# 22      1         Offence Against a Person
# 23      1         Other Theft
# 24      1         Offence Against a Person
# 25      1         Theft from Vehicle
# 26      1         Other Theft
# 27      1         Theft from Vehicle
# 28      1         Mischief
# 29      1         Vehicle Collision or Pedestrian Struck (with Injury)
# 30      1         Theft from Vehicle
# ⋮       ⋮         ⋮
# 2787171 50        Theft from Vehicle
# 2787172 50        Theft of Bicycle
# 2787173 50        Theft from Vehicle
# 2787174 50        Mischief
# 2787175 50        Other Theft
# 2787176 50        Theft of Vehicle
# 2787177 50        Other Theft
# 2787178 50        Break and Enter Residential/Other
# 2787179 50        Offence Against a Person
# 2787180 50        Other Theft
# 2787181 50        Theft from Vehicle
# 2787182 50        Offence Against a Person
# 2787183 50        Break and Enter Commercial
# 2787184 50        Offence Against a Person
# 2787185 50        Mischief
# 2787186 50        Break and Enter Residential/Other
# 2787187 50        Theft from Vehicle
# 2787188 50        Theft from Vehicle
# 2787189 50        Theft from Vehicle
# 2787190 50        Offence Against a Person
# 2787191 50        Theft from Vehicle
# 2787192 50        Other Theft
# 2787193 50        Offence Against a Person
# 2787194 50        Theft of Bicycle
# 2787195 50        Other Theft
# 2787196 50        Offence Against a Person
# 2787197 50        Offence Against a Person
# 2787198 50        Offence Against a Person
# 2787199 50        Other Theft
# 2787200 50        Offence Against a Person
#         NEIGHBOURHOOD
# 1       Strathcona
# 2       Strathcona
# 3       Strathcona
# 4       Strathcona
# 5       Strathcona
# 6       Strathcona
# 7       Strathcona
# 8       Strathcona
# 9       Strathcona
# 10      Strathcona
# 11      Strathcona
# 12      Strathcona
# 13      Strathcona
# 14      Strathcona
# 15      Strathcona
# 16      Strathcona
# 17      Strathcona
# 18      Strathcona
# 19      Strathcona
# 20      Strathcona
# 21      Strathcona
# 22      Strathcona
# 23      Strathcona
# 24      Strathcona
# 25      Strathcona
# 26      Strathcona
# 27      Strathcona
# 28      Strathcona
# 29      Strathcona
# 30      Strathcona
# ⋮       ⋮
# 2787171 Strathcona
# 2787172 Strathcona
# 2787173 Strathcona
# 2787174 Strathcona
# 2787175 Strathcona
# 2787176 Strathcona
# 2787177 Strathcona
# 2787178 Strathcona
# 2787179 Strathcona
# 2787180 Strathcona
# 2787181 Strathcona
# 2787182 Strathcona
# 2787183 Strathcona
# 2787184 Strathcona
# 2787185 Strathcona
# 2787186 Strathcona
# 2787187 Strathcona
# 2787188 Strathcona
# 2787189 Strathcona
# 2787190 Strathcona
# 2787191 Strathcona
# 2787192 Strathcona
# 2787193 Strathcona
# 2787194 Strathcona
# 2787195 Strathcona
# 2787196 Strathcona
# 2787197 Strathcona
# 2787198 Strathcona
# 2787199 Strathcona
# 2787200 Strathcona

# %%
mount_pleasant_sample_prop <- mount_pleasant_sample %>%
    summarise(prop = sum(TYPE == "Theft from Vehicle")/nrow(mount_pleasant_sample))

strathcona_sample_prop <- strathcona_sample %>%
    summarise(prop = sum(TYPE == "Theft from Vehicle")/nrow(strathcona_sample))


mount_pleasant_ci <- mount_pleasant_sample_prop %>%
    get_ci(level = 0.95, type = "percentile")

strathcona_ci <- strathcona_sample_prop %>%
    get_ci(level = 0.95, type = "percentile")



mount_pleasant_ci
strathcona_ci
# Out:
#   lower_ci    upper_ci
# 1 0.004818292 0.00493655
#   lower_ci    upper_ci
# 1 0.004663668 0.004777528

# %%
obs_diff_prop_theft <- crime_mp_s %>% 
    specify(formula = TYPE ~ NEIGHBOURHOOD, success = "Theft from Vehicle") %>%
    hypothesise(null = 'independence') %>%
    summarise(stat = (sum(TYPE == "Theft from Vehicle" & NEIGHBOURHOOD == "Mount Pleasant") / proportion$total_number_of_crime[2])
                 - (sum((TYPE == "Theft from Vehicle" & NEIGHBOURHOOD == "Strathcona") / proportion$total_number_of_crime[1])))  %>%
    mutate(stat = stat + (0 - mean(stat)))

obs_diff_prop_offence <- crime_mp_s %>% 
    specify(formula = TYPE ~ NEIGHBOURHOOD, success = "Offence Against a Person") %>%
    hypothesise(null = 'independence') %>%
    summarise(stat = (sum(TYPE == "Offence Against a Person" & NEIGHBOURHOOD == "Mount Pleasant") / proportion$total_number_of_crime[2])
                 - (sum((TYPE == "Offence Against a Person" & NEIGHBOURHOOD == "Strathcona") / proportion$total_number_of_crime[1])))  %>%
    mutate(stat = stat + (0 - mean(stat)))


obs_diff_prop_theft
obs_diff_prop_offence
# Out:
# Dropping unused factor levels c("Theft of Bicycle", "Theft of Vehicle", "Vehicle Collision or Pedestrian Struck (with Fatality)", "Vehicle Collision or Pedestrian Struck (with Injury)", "Break and Enter Commercial", "Break and Enter Residential/Other", "Homicide", "Mischief", "Other Theft") from the supplied response variable 'TYPE'.
#
# Dropping unused factor levels c("Strathcona", "Sunset", "Kensington-Cedar Cottage", "Central Business District", "Fairview", "Grandview-Woodland", "West End", "Hastings-Sunrise", "Shaughnessy", "Kitsilano", "Marpole", "Stanley Park", "Oakridge", "Riley Park", "West Point Grey", "Victoria-Fraserview", "Kerrisdale", "Arbutus Ridge", "Renfrew-Collingwood", "Musqueam", "Killarney", "Dunbar-Southlands", "South Cambie") from the supplied explanatory variable 'NEIGHBOURHOOD'.
#
# Dropping unused factor levels c("Theft of Bicycle", "Theft of Vehicle", "Vehicle Collision or Pedestrian Struck (with Fatality)", "Vehicle Collision or Pedestrian Struck (with Injury)", "Break and Enter Commercial", "Break and Enter Residential/Other", "Homicide", "Mischief", "Other Theft") from the supplied response variable 'TYPE'.
#
# Dropping unused factor levels c("Strathcona", "Sunset", "Kensington-Cedar Cottage", "Central Business District", "Fairview", "Grandview-Woodland", "West End", "Hastings-Sunrise", "Shaughnessy", "Kitsilano", "Marpole", "Stanley Park", "Oakridge", "Riley Park", "West Point Grey", "Victoria-Fraserview", "Kerrisdale", "Arbutus Ridge", "Renfrew-Collingwood", "Musqueam", "Killarney", "Dunbar-Southlands", "South Cambie") from the supplied explanatory variable 'NEIGHBOURHOOD'.
#   stat
# 1 0
#   stat
# 1 0

# %%
options(repr.plot.width = 10, repr.plot.height = 5)
mount_pleasant_sample_prop_plot <- mount_pleasant_sample_prop %>%
      ggplot(aes(x = prop)) +
      geom_histogram(binwidth = 1/100000, color = "white", boundary = 1990) +
      ggtitle("Proportion distribution of Theft from Vehicle in Mount Pleasant") +
      geom_vline(xintercept = mount_pleasant_ci$lower_ci, color = "red", lwd=2) +
      geom_vline(xintercept = mount_pleasant_ci$upper_ci, color = "red", lwd=2) +
    theme(text=element_text(size=15)) +
      labs(x = "Resample Proportion of Theft from Vehicle", y="Count")

strathcona_sample_prop_plot <- strathcona_sample_prop %>%
    ggplot(aes(x = prop)) +
  geom_histogram(binwidth = 1/100000, color = "white", boundary = 1990) +
    ggtitle("Proportion distribution of Theft from Vehicle in Strathcona") +
      geom_vline(xintercept = strathcona_ci$lower_ci, color = "red", lwd=2) +
      geom_vline(xintercept = strathcona_ci$upper_ci, color = "red", lwd=2) +
    theme(text=element_text(size=15)) +
  labs(x = "Resample Proportion of Theft from Vehicle", y="Count")


mount_pleasant_sample_prop_plot
strathcona_sample_prop_plot
# Out:
# plot without title
# plot without title

# %%
mount_pleasant_sd <- mount_pleasant_sample_prop %>%
    summarize(SE = sd(prop))

strathcona_sd <- strathcona_sample_prop %>%
    summarize(SE = sd(prop))


mount_pleasant_sd
strathcona_sd
# Out:
#   SE
# 1 3.447008e-05
#   SE
# 1 3.403006e-05

# %%
# confidence interval offence

mount_pleasant_sample_offence_prop <- mount_pleasant_sample %>%
    summarise(prop = sum(TYPE == "Offence Against a Person")/nrow(mount_pleasant_sample))

strathcona_sample_offence_prop <- strathcona_sample %>%
    summarise(prop = sum(TYPE == "Offence Against a Person")/nrow(strathcona_sample))


mount_pleasant_offence_ci <- mount_pleasant_sample_prop %>%
    get_ci(level = 0.95, type = "percentile")

strathcona_offence_ci <- strathcona_sample_prop %>%
    get_ci(level = 0.95, type = "percentile")



mount_pleasant_offence_ci
strathcona_offence_ci
# Out:
#   lower_ci    upper_ci
# 1 0.004818292 0.00493655
#   lower_ci    upper_ci
# 1 0.004663668 0.004777528

# %%
options(repr.plot.width = 10, repr.plot.height = 5)
mount_pleasant_sample_prop_plot_offence <- mount_pleasant_sample_prop %>%
      ggplot(aes(x = prop)) +
      geom_histogram(binwidth = 1/100000, color = "white", boundary = 1990) +
      ggtitle("Proportion distribution of Offence Against a Person in Mount Pleasant") +
      geom_vline(xintercept = mount_pleasant_offence_ci$lower_ci, color = "red", lwd=2) +
      geom_vline(xintercept = mount_pleasant_offence_ci$upper_ci, color = "red", lwd=2) +
    theme(text=element_text(size=15)) +
      labs(x = "Resample Proportion of Offence Against a Person", y="Count")

strathcona_sample_prop_plot_offence <- strathcona_sample_prop %>%
    ggplot(aes(x = prop)) +
  geom_histogram(binwidth = 1/100000, color = "white", boundary = 1990) +
    ggtitle("Proportion distribution of Offence Against a Person in Strathcona") +
      geom_vline(xintercept = strathcona_offence_ci$lower_ci, color = "red", lwd=2) +
      geom_vline(xintercept = strathcona_offence_ci$upper_ci, color = "red", lwd=2) +
    theme(text=element_text(size=15)) +
  labs(x = "Resample Proportion of Offence Against a Person", y="Count")


mount_pleasant_sample_prop_plot_offence
strathcona_sample_prop_plot_offence
# Out:
# plot without title
# plot without title

# %%
z_test_result_theft <- tidy(
  prop.test(x = c(dataMP$n[1], dataS$n[1]),
            n = c(proportion$total_number_of_crime[2], proportion$total_number_of_crime[1]),
            correct = FALSE,
            alternative = "greater")
)

z_test_result_offence <- tidy(
  prop.test(x = c(dataMP$n[10], dataS$n[10]),
            n = c(proportion$total_number_of_crime[2], proportion$total_number_of_crime[1]),
            correct = FALSE,
            alternative = "greater")
)

z_test_result_theft
z_test_result_offence

# %%
set.seed(1)
options(repr.plot.width = 12, repr.plot.height = 10)
null_model_theft <- crime_mp_s %>% 
    specify(formula = TYPE ~ NEIGHBOURHOOD, success = "Theft from Vehicle") %>%
    generate(reps = 200, type = 'bootstrap') %>%
    hypothesise(null = 'independence') %>%
    group_by(replicate) %>%
    summarise(stat = (sum(TYPE == "Theft from Vehicle" & NEIGHBOURHOOD == "Mount Pleasant") / proportion$total_number_of_crime[2])
                 - (sum((TYPE == "Theft from Vehicle" & NEIGHBOURHOOD == "Strathcona") / proportion$total_number_of_crime[1])))  %>%

    mutate(stat = stat + (0 - mean(stat)))

null_dist_plot_theft <- null_model_theft %>%
    ggplot() +
    geom_histogram(aes(x = stat), binwidth =1/4000) +
    labs(x='Difference in Proportion between Mount Pleasant & Strathcona (Theft from Vehicle)', y='Count')+
    ggtitle('Null Model Distribution (Theft from Vehicle)')

    

null_dist_plot_theft

# %%
set.seed(1)
options(repr.plot.width = 12, repr.plot.height = 10)

null_model_offence <- crime_mp_s %>% 
    specify(formula = TYPE ~ NEIGHBOURHOOD, success = "Offence Against a Person") %>%
    generate(reps = 200, type = 'bootstrap') %>%
    hypothesise(null = 'independence') %>%
    group_by(replicate) %>%
    summarise(stat = (sum(TYPE == "Offence Against a Person" & NEIGHBOURHOOD == "Mount Pleasant") / proportion$total_number_of_crime[2])
                 - (sum((TYPE == "Offence Against a Person" & NEIGHBOURHOOD == "Strathcona") / proportion$total_number_of_crime[1])))  %>%
    mutate(stat = stat + (0 - mean(stat)))

null_dist_plot_offence <- null_model_offence %>%
    ggplot() +
    geom_histogram(aes(x = stat), binwidth =1/4000) +
    labs(x='Difference in Proportion between Mount Pleasant & Strathcona (Offence Against a Person)', y='Count') +
    ggtitle('Null Model Distribution (Offence Against a Person)')

    

null_dist_plot_offence

# %%
##??
p_value_theft <- null_model_theft %>%
    summarise(p_value = mean(null_model_theft$stat > obs_diff_prop_theft)) %>%
    mutate()

p_value_offence <- null_model_offence %>%
    summarise(p_value = mean(null_model_offence$stat > obs_diff_prop_offence))

#p_value <- rbind(p_value_theft, p_value_offence)



p_value_theft
p_value_offence
#p_value
